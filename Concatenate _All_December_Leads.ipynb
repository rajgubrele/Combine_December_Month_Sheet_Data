# %%
import pandas as pd
import datetime as dt

# %%
C:\Users\RAJG\Downloads\Python Conversion Data\Leads\Dec

# %%
dfll = pd.DataFrame()
for i in range(1,15):
    A = 'C://Users//RAJG//Downloads//Python Conversion Data//Leads//Dec//Dec (' + str(i) + ').csv'
    dfl=pd.read_csv(A, on_bad_lines='skip')
    dfll = pd.concat([dfll,dfl])
    print(i)
    print(dfl)
print(dfll)
# Out:
# 1
#              UTM Source         UTM Medium  \
# 0     WhatsApp Business  WhatsApp Business
# 1              Facebook                CPL
# 2     WhatsApp Business  WhatsApp Business
# 3     WhatsApp Business  WhatsApp Business
# 4     WhatsApp Business  WhatsApp Business
# ...                 ...                ...
# 2139  WhatsApp Business  WhatsApp Business
# 2140                NaN                NaN
# 2141                NaN                NaN
# 2142                NaN                NaN
# 2143                NaN                NaN
#
#                                            UTM Campaign           UTM Term  \
# 0                                     WhatsApp Business  WhatsApp Business
# 1     Rx_HMC_Corporate_Lead_Plan22_India_Auction_web...        Lead_Plan22
# 2                                     WhatsApp Business  WhatsApp Business
# 3                                     WhatsApp Business  WhatsApp Business
# ...

# %%
# Save the DataFrame into CSV

dfll.to_csv('C://Users//RAJG//Downloads//Python Conversion Data//Leads//Dec//Dec.csv')

print('File saved Successfully')
# Out:
# File saved Successfully

# %% [raw]
# Concatenate December SQL Data

# %%
dfsll = pd.DataFrame()
for j in range(1,17):
    B = 'C://Users//RAJG//Downloads//Python Conversion Data//Leads//Dec//Dec//Dec (' + str(j) + ').csv'
    dfsl=pd.read_csv(A, on_bad_lines='skip')
    dfsll = pd.concat([dfsll,dfsl])
    print(j)
    print(dfsl)
print(dfsll)
# Out:
# 1
#      UTM Source UTM Medium                                       UTM Campaign  \
# 0       hgpmart        NaN                                                NaN
# 1           NaN        NaN                                                NaN
# 2           NaN        NaN                                                NaN
# 3      Facebook        CPL  Rx_HMC_Corporate_Lead_Plan22_India_Auction_web...
# 4           NaN        NaN                                                NaN
# ...         ...        ...                                                ...
# 8422   Facebook        CPL  Rx_HMC_Corporate_Lead_Plan22_India_Auction_web...
# 8423   Facebook        CPL  Rx_HMC_Corporate_Lead_Plan22_India_Auction_web...
# 8424   Facebook        CPL  Rx_HMC_Corporate_Lead_Plan22_India_Auction_web...
# 8425        NaN        NaN                                                NaN
# 8426        NaN        NaN                                                NaN
#
# ...
